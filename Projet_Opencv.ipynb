# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Opencv_master
# Out:
# /content/drive/MyDrive/Opencv_master

# %% [markdown]
# # PROJET

# %% [markdown]
# Écrivez un code qui prend une image bien claire (sans overlapping) de la monnaie de rechange et affiche le montant d'argent présent.
#
# <img src="http://datagenetics.com/blog/december42012/all.png">

# %% [markdown]
# # Les critères pour differencier une pièce de monnaie d'une autre:
# *   La taille
# *   La couleur

# %% [markdown]
# # Les taches à suivre:
# 1.  Une image seule pièce de monnaie. **1dh**
# 1.  Une image avec 2 pièces de monnaie. **1dh et 10dh**
# 2.  Ajouter une troisième pièce. **5dh**
# 3.  Travailler avec toutes les pièces existantes.

# %% [markdown]
# # Utilisez matlab et opencv
